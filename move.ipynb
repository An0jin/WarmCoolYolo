# %% [markdown]
# # 파일 옮기기

# %%
import os
import shutil

files=list(filter(lambda x : "." in x ,os.listdir("./test")))
files
# Out:
# ['fw_1.jpg',
#  'fw_1.txt',
#  'fw_10.jpg',
#  'fw_10.txt',
#  'fw_2.jpg',
#  'fw_2.txt',
#  'fw_3.jpg',
#  'fw_3.txt',
#  'fw_4.jpg',
#  'fw_4.txt',
#  'fw_5.jpg',
#  'fw_5.txt',
#  'fw_6.jpg',
#  'fw_6.txt',
#  'fw_7.jpg',
#  'fw_7.txt',
#  'fw_8.jpg',
#  'fw_8.txt',
#  'fw_9.jpg',
#  'fw_9.txt',
#  'fw_img1.png',
#  'fw_img1.txt',
#  'fw_img2.png',
#  'fw_img2.txt',
#  'fw_img3.png',
#  'fw_img3.txt',
#  'fw_img4.png',
#  'fw_img4.txt',
#  'fw_img5.png',
#  'fw_img5.txt',
#  'fw_img6.png',
#  'fw_img6.txt',
#  'fw_img7.png',
#  'fw_img7.txt',
#  'labels.cache',
#  'sc_1.png',
#  'sc_1.txt',
#  'sc_10.jpg',
#  'sc_10.txt',
#  'sc_2.png',
#  'sc_2.txt',
#  'sc_3.jpg',
#  'sc_3.txt',
#  'sc_4.jpg',
#  'sc_4.txt',
#  'sc_5.PNG',
#  'sc_5.txt',
#  'sc_6.PNG',
#  'sc_6.txt',
#  'sc_7.jpg',
#  'sc_7.txt',
#  'sc_8.PNG',
#  'sc_8.txt',
#  'sc_9.jpg',
#  'sc_9.txt',
#  'sc_img1.png',
#  'sc_img1.txt',
#  'sc_img2.png',
#  'sc_img2.txt',
#  'sc_img3.png',
#  'sc_img3.txt',
# ...

# %%
path="./test"
for i in files:
    shutil.move(os.path.join(path,i),os.path.join(path,"labels" if i.endswith(".txt") else "images",i))
